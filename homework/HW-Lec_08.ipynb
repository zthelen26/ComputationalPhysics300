# %%
#generate a data with random noise
#choose different polynomial function to fit the data
#discuss which polynomial function yields the best fit and give your reasoning.

# %%
#generate data with random noise

import numpy as np
import matplotlib.pyplot as plt

np.random.seed(5)
np.set_printoptions(precision = 2) #sig fig. 

x = np.random.randn(10)
y = np.random.randn(10)
print(x,y)

plt.plot(x,y,'o', label = 'Points')
# Out:
# [ 0.44 -0.33  2.43 -0.25  0.11  1.58 -0.91 -0.59  0.19 -0.33] [-1.19 -0.2  -0.36  0.6  -1.66 -0.7   1.15  1.86 -1.51  0.64]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=[12, 8])
#define the function
f = lambda x: (x * np.cos(x))**2  

#define the paramters for the plot
a,b = 0,3
npoints = 100
order = 10

x = np.linspace(a,b,npoints)
y = f(x) + np.random.rand(npoints) - 0.5

fit = np.polyfit(x, y, order, full=True)
ypoints = np.polyval(fit[0], x)

plt.plot(x,f(x), label='ideal function')
plt.plot(x,y, 'o', label='noisy data')
plt.plot(x,ypoints, label='polyfit'+str(order))

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([a,b])
plt.legend(fontsize=12)
plt.title('fitted coefficients' + str(fit[0]) + '\n residual: ' + str(fit[1]))
plt.show()

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=[10, 6])


#define the function
f = lambda x,a,b,c: (a*np.cos(b*x)+c)**2  

#define the paramters for the plot
x_min, x_max = 0, 3
npoints = 100
a,b,c = 1.5, 2, 1e-15

x = np.linspace(x_min, x_max, npoints)
y = f(x,a,b,c) + np.random.rand(npoints) - 0.5

#do the curve fit
params, extras = curve_fit(f, x, y)

plt.plot(x,f(x,a,b,c), '--', label='ideal function')
plt.plot(x,y, 'o', label='noisy data')
plt.plot(x,f(x,params[0],params[1],params[2]), label='curve_fit')

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([x_min, x_max])
plt.legend(fontsize=12)
plt.show()
print('original coefficients: %6.3f, %6.3f, %6.3f' %(a,b,c))
print('fitted   coefficients: %6.3f, %6.3f, %6.3f' %(params[0], params[1], params[2]))
# Out:
# original coefficients:  1.500,  2.000,  0.000
# fitted   coefficients:  0.056,  1.185,  1.021

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=[6, 4])

f = lambda x:np.random.seed(10)
np.set_printoptions(precision = 2) #sig fig. 

npoints = 10
x = np.random.rand(npoints)
y = np.random.rand(npoints)
print(x,y)

order = 1

fit = np.polyfit(x, y, order, full=True)
ypoints = np.polyval(fit[0], x)


plt.plot(x,y, 'o', label='noisy data')
plt.plot(x,ypoints, label='polyfit'+str(order))
plt.legend()
plt.show
# Out:
# [0.5  0.36 0.88 0.53 0.15 0.08 0.57 0.78 0.41 0.53] [0.81 0.65 0.61 0.89 0.16 0.17 0.94 0.81 0.98 0.53]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=[10, 6])

f = lambda x:np.random.seed(10)
np.set_printoptions(precision = 2) #sig fig. 

npoints = 10
x = np.random.rand(npoints)
y = np.random.rand(npoints)
print(x,y)


params, extras = curve_fit(f, x, y)

plt.plot(x,f(x,a,b,c), '--', label='ideal function')
plt.plot(x,y, 'o', label='noisy data')
plt.plot(x,f(x), label='curve_fit')

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([x_min, x_max])
plt.legend(fontsize=12)
plt.show()
# Out:
# [0.59 0.79 0.92 0.58 0.55 0.93 0.69 0.79 0.51 0.99] [0.56 0.14 0.04 0.84 0.09 0.59 0.5  0.81 0.37 0.17]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-4b1bb7f51075> in <module>
#      14
#      15
# ---> 16 params, extras = curve_fit(f, x, y)
#      17
#      18 plt.plot(x,f(x,a,b,c), '--', label='ideal function')
#
# E:\zthel\Documents\ANACONDA\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     707         args = sig.args
#     708         if len(args) < 2:
# --> 709             raise ValueError("Unable to determine number of fit parameters.")
#     710         n = len(args) - 1
#     711     else:
#
# ValueError: Unable to determine number of fit parameters.

# %%
#Polyfit function does a better job on fitting completely random data. 
#Curved_fit needs certain parameters to fucntion properly. More accuarate and useful so long as you have a known equation.
#with an unknown equation and completely random data points poly fit yields the best results.
